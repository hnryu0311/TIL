# %%
import matplotlib.pyplot as mpl
# 폰트 설정
mpl.rc('font', family='NanumGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# #### 연습문제 7.1.1
# - 꽃잎 길이의 분포는 단봉분포인가 다봉분포인가?
# - 데이터프레임에서 종(species)이 setosa인 데이터만 뽑아서 히스토그램을 그려라. 이 분포는 단봉분포인가 다봉분포인가?

# %%
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
sy = pd.Series(iris.target, dtype="category")
sy = sy.cat.rename_categories(iris.target_names)
df['species'] = sy

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
x = df["petal length (cm)"].values
x
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
import seaborn as sns

# %%
sns.distplot(x)

# %%
x1 = df[df.species == "setosa"]["petal length (cm)"].values
x1
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4])

# %%
sns.distplot(x1)

# %% [markdown]
# #### 연습문제 7.1.2
# -  virginica 종 붓꽃의 꽃잎 길이(petal length) 데이터에 대해 표본평균, 표본중앙값, 표본최빈값을 구하고 위와 같이 그림으로 그려라. 표본최빈값을 구할 때는 0cm부터 10cm까지 1cm 간격으로 히스토그램을 그려서 표본최빈값을 구하라.
# - 히스토그램의 구간 수를 50개, 100개로 세분화하여 다시 표본최빈값을 구하라. 표본최빈값이 어떻게 달라지는가?

# %%
x3 = df[df.species=="virginica"]["petal length (cm)"].values

# %%
sns.distplot(x3)

# %%
import matplotlib.pyplot as plt

# %%
x3 = df[df.species=="virginica"]["petal length (cm)"].values
sns.distplot(x3)
bins = np.linspace(0,10,10 * 4 +1)
ns, _ = np.histogram(x,bins=bins)

sample_mean = np.mean(x3)
sample_median = np.median(x3)
mode_index = np.argmax(x3)
sample_mode = 0.5 * (bins[mode_index] + bins[mode_index + 1])


plt.axvline(sample_mean, c='k', ls=":", label="표본평균")
plt.axvline(sample_median, c='k', ls="--", label="표본중앙값")
plt.axvline(sample_mode, c='k', ls="-", label="표본최빈값")

plt.title("표본평균, 표본중앙값, 표본최빈값의 차이")
plt.xlabel("x")
plt.legend()
plt.show()

# %%
x = df[df.species == "virginica"]["petal length (cm)"]

def sample_statistics(x, n, x_min=0, x_max=10):
    bins = np.linspace(x_min, x_max, n + 1)
    ns, _ = np.histogram(x, bins=bins)
    sample_mean = np.mean(x)
    sample_median = np.median(x)
    mode_index = np.argmax(ns)
    sample_mode = 0.5 * (bins[mode_index] + bins[mode_index + 1])
    print("구간이 {}개일 때".format(n))
    print("표본평균", sample_mean)
    print("표본중앙값", sample_median)
    print("표본최빈값", sample_mode)

    sns.distplot(x, bins=bins)
    plt.axvline(sample_mean, c='k', ls=":", label="표본평균")
    plt.axvline(sample_median, c='k', ls="--", label="표본중앙값")
    plt.axvline(sample_mode, c='k', ls="-", label="표본최빈값")
    plt.title("표본평균, 표본중앙값, 표본최빈값의 차이")
    plt.xlabel("x")
    plt.legend()
    plt.show()

# %%
sample_statistics(x,10)
# Out:
# 구간이 10개일 때
# 표본평균 5.552
# 표본중앙값 5.55
# 표본최빈값 5.5

# %%
sample_statistics(x,50)
# Out:
# 구간이 50개일 때
# 표본평균 5.552
# 표본중앙값 5.55
# 표본최빈값 5.5

# %% [markdown]
# #### 기댓값과 표본평균의 관계
# #### 연습문제 7.3.3
# - 넘파이를 사용하여 숫자 100개를생성, 표본 집합을 구한다.
# - 이 표본집합을 확률번수 X1의 표본이라고 하자. X1의 표본 분산을 계산.
#
# - 같은 작업을 50번 반복하여 확률변수 X2, X3 ... X50의 표본집합을 구한다.

# %%
ls_x_mean = []
for i in range(50):
    x = np.random.normal(size=100)
    x_mean = x.mean()
    ls_x_mean.append(x_mean)

# %%
x
# Out:
# array([ 2.96935234e-01, -9.81462796e-02,  1.80555570e+00, -8.39630275e-01,
#        -5.44765093e-01,  9.15376877e-01,  4.15087957e-02, -1.00612378e+00,
#         5.07203782e-01, -4.13424607e-01,  1.38241403e+00, -2.68488539e-01,
#         6.37005453e-02,  1.60502129e-01,  8.76888929e-01,  4.45476720e-01,
#         5.85756717e-01,  1.63820828e-01,  2.14598350e-01,  6.91857056e-02,
#         7.39792484e-01,  5.67470237e-01,  1.13493145e+00,  1.65819719e+00,
#         1.03376195e+00, -3.03909870e+00,  2.08352730e-01,  1.18945622e+00,
#         1.61738022e+00,  1.80345865e-01, -1.83882715e-01, -1.09185788e+00,
#        -5.07501763e-01,  6.19396921e-01, -1.19642937e+00, -4.98923683e-01,
#         1.85532585e-01,  9.39618097e-01,  1.61450388e-04,  1.76082465e+00,
#         5.90762581e-01,  1.12896614e+00,  2.15573890e+00,  1.14993999e+00,
#         1.36569367e+00, -2.30143205e-01,  4.25259607e-01, -8.11927666e-01,
# ...

# %%
ls_x_mean
# Out:
# [-0.08696748003726042,
#  0.06712794835304187,
#  -0.19462935464236225,
#  0.17714663264722566,
#  0.008428868941274313,
#  0.13618819134794158,
#  -0.0658096752115565,
#  -0.16702967529392054,
#  -0.0649022114006535,
#  0.01955691372490469,
#  0.10424171304036721,
#  0.023637472331512845,
#  0.07254315412533759,
#  -0.3466938110174243,
#  -0.025395888006382053,
#  -0.08374138859339107,
#  0.12466826248030946,
#  0.022831245412884976,
#  0.07150752868688551,
#  0.027035317058140787,
#  -0.09768860250606673,
#  0.09631212275342482,
#  -0.17221491904045336,
#  -0.03894704974465717,
#  0.19943005609488457,
#  -0.006009728141202636,
#  -0.05895816997719014,
#  0.04796178139975078,
#  -0.011873761577775404,
#  0.07946292278932077,
#  -0.10871509806870261,
#  -0.07378917732017025,
#  -0.1522739192157324,
#  0.013592184218600954,
#  -0.03558228081759166,
#  0.010985718180757402,
#  0.09898086191344957,
#  -0.042393299124475654,
#  -0.0816612254163757,
#  0.04408809139568458,
# ...

# %%
sns.distplot(x)
plt.xlim(-5,5)
plt.show()

# %%
sns.distplot(ls_x_mean)
plt.xlim(-5,5)
plt.show()

# %%
plt.subplot(121)
sns.distplot(x)
plt.xlim(-5,5)
plt.subplot(122)
sns.distplot(ls_x_mean)
plt.xlim(-5,5)
# Out:
# (-5, 5)
